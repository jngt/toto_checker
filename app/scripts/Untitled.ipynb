# %%
import datetime
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import time
import os, requests
import re, zenhan, json

# %%
r = requests.get('http://sport-kuji.toto-dream.com/dci/I/IPA/IPA02.do?op=dispBIGLotAssignGameDetail&popupDispDiv=0&holdCntId=1077&bigLotInfoCommodityId=&commodityId=09')
soup = BeautifulSoup(r.text, "html.parser")

# %%
soup
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
#
# <html>
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="text/javascript" http-equiv="Content-Script-Type"/>
# <meta content="text/css" http-equiv="Content-Style-Type"/>
# <link href="/dci/css/P/PZZ/PZZ07/main.css" rel="stylesheet" type="text/css"/>
# <title>toto公式サイト-ロト６、宝くじと並ぶ高額当せんくじＢＩＧ。目指せ最高6億円！</title>
# <script src="//assets.adobedtm.com/3fb4a95d593e4b420e11f482b00de674bf8ed253/satelliteLib-fd2c7fee3ce1783ec86f3eca0f012a26a4f8db32.js"></script>
# <script src="/dci/js/P/PZZ/PZZOL/common.js" type="text/javascript"></script>
# <script src="/dci/js/P/PZZ/PZZOL/common_check.js" type="text/javascript"></script>
# <script src="/dci/js/P/PZZ/PZZOL/common_message.js" type="text/javascript"></script>
# <script type="text/javascript">
# <!--
# //販売スケジュールへ
# function doSubmitSchedule(form, op, action) {
#     if (submitOnce()) {
# ...

# %%
rows = soup.find_all('tr')

# %%
rows
# Out:
# [<tr>
#  <th width="119">
#  <img alt="BIG" height="39" src="http://sport-kuji.toto-dream.com/img_system/common/img_big.gif" width="117"/>
#  </th>
#  <td>第1077回　BIG　くじ指定試合</td>
#  </tr>, <tr>
#  <th class="type4" width="128">販売開始日</th>
#  <td class="type5">2019年03月09日（土）（ネット 13:50
#
#
#                                       ／toto取扱コンビニ 11:30
#
#
#
#
#                                       ／toto売り場 12:00）
#
#                                      </td>
#  </tr>, <tr>
#  <th class="type4">販売終了日</th>
#  <td class="type5">2019年03月16日（土）（ネット 13:50
#
#
#                                       ／toto取扱コンビニ 11:30
#
#
#
#                                       ／toto売り場 12:00）
#
#                                      </td>
#  </tr>, <tr>
#  <th class="type4">結果発表日</th>
#  <td class="type5">2019年03月17日（日）</td>
#  </tr>, <tr>
#  <th width="50"> </th>
#  <th width="78">開催日</th>
#  <th width="90">試合開始<br/>
#                                          予定時間</th>
#  <th width="86">競技場</th>
# ...

# %%
len(rows)
# Out:
# 19

# %%
rows[0]
# Out:
# <tr>
# <th width="119">
# <img alt="BIG" height="39" src="http://sport-kuji.toto-dream.com/img_system/common/img_big.gif" width="117"/>
# </th>
# <td>第1077回　BIG　くじ指定試合</td>
# </tr>

# %%
rows[1]
# Out:
# <tr>
# <th class="type4" width="128">販売開始日</th>
# <td class="type5">2019年03月09日（土）（ネット 13:50
#
#
#                                      ／toto取扱コンビニ 11:30
#
#
#
#
#                                      ／toto売り場 12:00）
#
#                                     </td>
# </tr>

# %%
rows[2]
# Out:
# <tr>
# <th class="type4">販売終了日</th>
# <td class="type5">2019年03月16日（土）（ネット 13:50
#
#
#                                      ／toto取扱コンビニ 11:30
#
#
#
#                                      ／toto売り場 12:00）
#
#                                     </td>
# </tr>

# %%
rows[3]
# Out:
# <tr>
# <th class="type4">結果発表日</th>
# <td class="type5">2019年03月17日（日）</td>
# </tr>

# %%
rows[4]
# Out:
# <tr>
# <th width="50"> </th>
# <th width="78">開催日</th>
# <th width="90">試合開始<br/>
#                                         予定時間</th>
# <th width="86">競技場</th>
# <th colspan="3">指定試合（ホームvsアウェイ）</th>
# </tr>

# %%
rows[5]
# Out:
# <tr class="backgray">
# <td>1</td>
# <td>03/16</td>
# <td>14:00</td>
# <td>ニッパツ</td>
# <td width="230">横浜ＦＣ</td>
# <td width="50">VS</td>
# <td>アルビレックス新潟</td>
# </tr>

# %%
tds = rows[5].find_all('td')

# %%
tds
# Out:
# [<td>1</td>,
#  <td>03/16</td>,
#  <td>14:00</td>,
#  <td>ニッパツ</td>,
#  <td width="230">横浜ＦＣ</td>,
#  <td width="50">VS</td>,
#  <td>アルビレックス新潟</td>]

# %%
tds[4].get_text()
# Out:
# '横浜ＦＣ'

# %%
tds[6].get_text()
# Out:
# 'アルビレックス新潟'

# %%
r = requests.get('http://sp.toto-dream.com/_xs1_/dci/sp/I/IMA/IMA01.do?op=forwardSalesTermtotoSP&holdCntId=1075#toto')
soup = BeautifulSoup(r.text, "html.parser")

# %%
soup
# Out:
# <?xml version="1.0" encoding="Shift_JIS"?>
# <!DOCTYPE html PUBLIC "-//i-mode group (ja)//DTD XHTML i-XHTML(Locale/Ver.=ja/1.0) 1.0//EN" "i-xhtml_4ja_10.dtd">
# <html><head><meta content="application/xhtml+xml;charset=utf-8" http-equiv="Content-type"/>
# <meta content="宝くじ,ロト6,ロト,宝くじ ネット,toto,BIG,トトカルチョ,ロトシックス,トト,ビッグ,,サッカーくじ" name="Keywords"/>
# <meta content="最高6億円くじ「BIG」が買える【totoオフィシャルサイト】。ロト６・宝くじと並ぶ高額当せんくじBIG。toto売場（一部宝くじ・ロト6売場）、toto取扱いコンビニ、ネットで購入できる。目指せ!最高6億円!!" name="Description"/>
# <meta content="width=320, initial-scale=1, minimum-scale=1, maximum-scale=1, user-scalable=no" name="viewport"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="no" name="apple-mobile-web-app-capable"/>
# <meta content="text/javascript" http-equiv="Content-Script-Type">
# <meta content="text/css" http-equiv="Content-Style-Type">
# <title>toto公式サイト-ロト６、宝くじと並ぶ高額当せんくじＢＩＧ。目指せ最高6億円！</title>
# ...

# %%
r = requests.get('https://www.toto-dream.com/toto/index.html')
soup = BeautifulSoup(r.text, "html.parser")

# %%
soup
# Out:
#  <!DOCTYPE html>
#
# <html prefix="og: http://ogp.me/ns#">
# <head>
# <script src="//assets.adobedtm.com/3fb4a95d593e4b420e11f482b00de674bf8ed253/satelliteLib-fd2c7fee3ce1783ec86f3eca0f012a26a4f8db32.js"></script>
# <meta charset="utf-8"/>
# <meta content="自分で予想して高額当せんが狙える「toto」公式サイト。種類も「toto」「mini toto」「totoGOAL3」と豊富。購入方法・当せん確認・販売スケジュールはこちら!
# " name="description">
# <meta content="telephone=no" name="format-detection"/>
# <meta content="toto,当せん,当選,くじ,予想,高額,サッカーくじ" name="keywords"/>
# <title>スポーツくじ「toto」｜楽しく予想して高額当せんのチャンス！</title>
# <meta content="totoトップについて紹介します。自分で予想して高額当せんが狙える「toto」公式サイト。種類も「toto」「mini toto」「totoGOAL3」と豊富。購入方法・当せん確認・販売スケジュールはこちら!" property="og:description"/>
# <meta content="totoトップ｜スポーツくじ「toto」" name="og:title"/>
# <meta content="toto公式サイト-ネットでも買える高額当せんくじBIG。目指せ億万長者！目指せ最高6億円！" property="og:site_name"/>
# <meta content="https://www.toto-dream.com/toto/index.html" property="og:url"/>
# ...

# %%
soup.tbody
# Out:
# <tbody id="top-totoTblBody">
# </tbody>

# %%
r = requests.get('http://sport-kuji.toto-dream.com/dci/I/IPA/IPA01.do?op=disptotoLotInfo&holdCntId=1075')
soup = BeautifulSoup(r.text, "html.parser")

# %%
soup
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
#
# <html>
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="text/javascript" http-equiv="Content-Script-Type"/>
# <meta content="text/css" http-equiv="Content-Style-Type"/>
# <link href="/dci/css/P/PZZ/PZZ07/main.css" rel="stylesheet" type="text/css"/>
# <title>toto公式サイト-ロト６、宝くじと並ぶ高額当せんくじＢＩＧ。目指せ最高6億円！</title>
# <script src="//assets.adobedtm.com/3fb4a95d593e4b420e11f482b00de674bf8ed253/satelliteLib-fd2c7fee3ce1783ec86f3eca0f012a26a4f8db32.js"></script>
# <script src="/dci/js/P/PZZ/PZZOL/common.js" type="text/javascript"></script>
# <script src="/dci/js/P/PZZ/PZZOL/common_check.js" type="text/javascript"></script>
# <script src="/dci/js/P/PZZ/PZZOL/common_message.js" type="text/javascript"></script>
# <script type="text/javascript">
#         <!--
#         function doSubmitOnce(form, op, action) {
#             if (submitOnce()) {
# ...

# %%
rows = soup.find_all('tr')

# %%
len(rows)
# Out:
# 74

# %%
rows[6]
# Out:
# <tr>
# <td>
#                                                     1
#                                                     </td>
# <td>03/09</td>
# <td>14:00</td>
# <td>札幌ド</td>
# <td width="185">北海道コンサドーレ札幌</td>
# <td width="50">VS</td>
# <td width="185">清水エスパルス</td>
# </tr>

# %%
rows[26]
# Out:
# <tr>
# <td>
#                                     第1075回 mini toto-A組 くじ情報
#                                 </td>
# <td class="textright">
# <a href="#" onclick="window.open('http://sport-kuji.toto-dream.com/dci/I/IPC/IPC01.do?op=initVoteRate&amp;holdCntId=1075&amp;commodityId=06', 'initVoteRate', 'width=900,height=600,scrollbars=1,resizable=1'); return false" onmouseout="swpimg('bt_tohyojyokyo')" onmouseover="swpimg('bt_tohyojyokyo')">
# <img alt="投票結果" border="0" height="26" id="bt_tohyojyokyo" name="bt_tohyojyokyo" src="http://sport-kuji.toto-dream.com/img_system/toto_kaisaikai_kujikekka/bt_tohyokekka.gif" width="93"/>
# </a>
# </td>
# </tr>

# %%
rows[25]
# Out:
# <tr>
# <th width="119">
# <img alt="minitoto" height="39" src="http://sport-kuji.toto-dream.com/img_system/common/img_minitoto.gif" width="117"/>
# </th>
# <td>
# <table border="0" cellpadding="0" cellspacing="0" class="adjustment" width="100%">
# <tr>
# <td>
#                                     第1075回 mini toto-A組 くじ情報
#                                 </td>
# <td class="textright">
# <a href="#" onclick="window.open('http://sport-kuji.toto-dream.com/dci/I/IPC/IPC01.do?op=initVoteRate&amp;holdCntId=1075&amp;commodityId=06', 'initVoteRate', 'width=900,height=600,scrollbars=1,resizable=1'); return false" onmouseout="swpimg('bt_tohyojyokyo')" onmouseover="swpimg('bt_tohyojyokyo')">
# <img alt="投票結果" border="0" height="26" id="bt_tohyojyokyo" name="bt_tohyojyokyo" src="http://sport-kuji.toto-dream.com/img_system/toto_kaisaikai_kujikekka/bt_tohyokekka.gif" width="93"/>
# </a>
# </td>
# </tr>
# </table>
# </td>
# </tr>

# %%
rows[25].find_all('td')
# Out:
# [<td>
#  <table border="0" cellpadding="0" cellspacing="0" class="adjustment" width="100%">
#  <tr>
#  <td>
#                                      第1075回 mini toto-A組 くじ情報
#                                  </td>
#  <td class="textright">
#  <a href="#" onclick="window.open('http://sport-kuji.toto-dream.com/dci/I/IPC/IPC01.do?op=initVoteRate&amp;holdCntId=1075&amp;commodityId=06', 'initVoteRate', 'width=900,height=600,scrollbars=1,resizable=1'); return false" onmouseout="swpimg('bt_tohyojyokyo')" onmouseover="swpimg('bt_tohyojyokyo')">
#  <img alt="投票結果" border="0" height="26" id="bt_tohyojyokyo" name="bt_tohyojyokyo" src="http://sport-kuji.toto-dream.com/img_system/toto_kaisaikai_kujikekka/bt_tohyokekka.gif" width="93"/>
#  </a>
#  </td>
#  </tr>
#  </table>
#  </td>, <td>
#                                      第1075回 mini toto-A組 くじ情報
#                                  </td>, <td class="textright">
# ...

# %%
r = rows[25].find_all('td')

# %%
text = r[0].get_text().replace(' ', '').replace('\n', '').replace('\r', '')

# %%
re.findall(r'[a-z]+' , text)
# Out:
# ['minitoto']

# %%
re.findall(r'[A-Z]+' , text)
# Out:
# ['A']

# %%
r = rows[25].find_all('td')
text = r[0].get_text().replace(' ', '').replace('\n', '').replace('\r', '')
re.findall(r'[A-Z]+' , text)
# Out:
# ['A']

# %%
r = rows[24].find_all('td')
text = r[0].get_text().replace(' ', '').replace('\n', '').replace('\r', '')
re.findall(r'[A-Z]+' , text)
# Out:
# []

# %%
r = rows[26].find_all('td')
text = r[0].get_text().replace(' ', '').replace('\n', '').replace('\r', '')
re.findall(r'[A-Z]+' , text)
# Out:
# ['A']

# %%
r = rows[27].find_all('td')
text = r[0].get_text().replace(' ', '').replace('\n', '').replace('\r', '')
a = re.findall(r'[A-Z]+' , text)

# %%
r = rows[26].find_all('td')
text = r[0].get_text().replace(' ', '').replace('\n', '').replace('\r', '')
re.findall(r'[a-z]+' , text) + re.findall(r'[A-Z]+' , text)
# Out:
# ['minitoto', 'A']

# %%
r = rows[26].find_all('td')
text = r[0].get_text().replace(' ', '').replace('\n', '').replace('\r', '')
re.findall(r'[a-zA-Z]+' , text)
# Out:
# ['minitoto', 'A']

# %%
r = rows[0].find_all('td')
text = r[0].get_text().replace(' ', '').replace('\n', '').replace('\r', '')
re.findall(r'[a-zA-Z]+' , text)
# Out:
# ['toto']

# %%
text
# Out:
# '第1075回totoくじ情報'

# %%
r = rows[6].find_all('td')
r
# Out:
# [<td>
#                                                      1
#                                                      </td>,
#  <td>03/09</td>,
#  <td>14:00</td>,
#  <td>札幌ド</td>,
#  <td width="185">北海道コンサドーレ札幌</td>,
#  <td width="50">VS</td>,
#  <td width="185">清水エスパルス</td>]

# %%
text
# Out:
# '2019年03月09日（土）（ネット13:50／toto取扱コンビニ11:30／toto売り場12:00)'

# %%
for row in rows:
    print(row)
    print('----------------')
# Out:
# <tr>
# <th width="119">
# <img alt="toto" height="39" src="http://sport-kuji.toto-dream.com/img_system/common/img_toto.gif" width="117"/>
# </th>
# <td>
# <table border="0" cellpadding="0" cellspacing="0" class="adjustment" width="100%">
# <tr>
# <td>
#                                     第1075回 toto くじ情報
#                                 </td>
# <td class="textright">
# <a href="#" onclick="window.open('http://sport-kuji.toto-dream.com/dci/I/IPC/IPC01.do?op=initVoteRate&amp;holdCntId=1075&amp;commodityId=01', 'initVoteRate', 'width=900,height=600,scrollbars=1,resizable=1'); return false" onmouseout="swpimg('bt_tohyojyokyo')" onmouseover="swpimg('bt_tohyojyokyo')">
# <img alt="投票結果" border="0" height="26" id="bt_tohyojyokyo" name="bt_tohyojyokyo" src="http://sport-kuji.toto-dream.com/img_system/toto_kaisaikai_kujikekka/bt_tohyokekka.gif" width="93"/>
# </a>
# </td>
# </tr>
# </table>
# </td>
# </tr>
# ----------------
# <tr>
# <td>
# ...

# %%
tds = []

# %%
if tds:
    print('--')

# %%
text = ['minitoto', 'A']

# %%
a += t for t in text
# Out:
#   File "<ipython-input-135-283a8e14678e>", line 1
#     a += t for t in text
#              ^
# SyntaxError: invalid syntax

# %%
''.join(text)
# Out:
# 'minitotoA'

# %%
rows[6]
# Out:
# <tr>
# <td>
#                                                     1
#                                                     </td>
# <td>03/09</td>
# <td>14:00</td>
# <td>札幌ド</td>
# <td width="185">北海道コンサドーレ札幌</td>
# <td width="50">VS</td>
# <td width="185">清水エスパルス</td>
# </tr>

# %%
rows[31]
# Out:
# <tr>
# <td>
#                                                     1
#                                                     </td>
# <td>03/09</td>
# <td>14:00</td>
# <td>札幌ド</td>
# <td width="185">北海道コンサドーレ札幌</td>
# <td width="50">VS</td>
# <td width="185">清水エスパルス</td>
# </tr>

# %%
tds = rows[6].find_all('td')

# %%
tds[4].get_text()
# Out:
# '北海道コンサドーレ札幌'

# %%
url = 'http://sport-kuji.toto-dream.com/dci/I/IPA/IPA02.do?op=dispBIGLotAssignGameDetail&popupDispDiv=0&holdCntId=1075&bigLotInfoCommodityId=&commodityId=09'

# %%
r = requests.get(url)
soup = BeautifulSoup(r.text, "html.parser")

# %%
soup
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
#
# <html>
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="text/javascript" http-equiv="Content-Script-Type"/>
# <meta content="text/css" http-equiv="Content-Style-Type"/>
# <link href="/dci/css/P/PZZ/PZZ07/main.css" rel="stylesheet" type="text/css"/>
# <title>toto公式サイト-ロト６、宝くじと並ぶ高額当せんくじＢＩＧ。目指せ最高6億円！</title>
# <script src="//assets.adobedtm.com/3fb4a95d593e4b420e11f482b00de674bf8ed253/satelliteLib-fd2c7fee3ce1783ec86f3eca0f012a26a4f8db32.js"></script>
# <script src="/dci/js/P/PZZ/PZZOL/common.js" type="text/javascript"></script>
# <script src="/dci/js/P/PZZ/PZZOL/common_check.js" type="text/javascript"></script>
# <script src="/dci/js/P/PZZ/PZZOL/common_message.js" type="text/javascript"></script>
# <script type="text/javascript">
# <!--
# //販売スケジュールへ
# function doSubmitSchedule(form, op, action) {
#     if (submitOnce()) {
# ...

# %%
rows = soup.find_all('tr')

# %%
for r in range(len(rows)):
    print(r)
    print(rows[r])
    print('----------------')
# Out:
# 0
# <tr>
# <th width="119">
# <img alt="BIG" height="39" src="http://sport-kuji.toto-dream.com/img_system/common/img_big.gif" width="117"/>
# </th>
# <td>第1075回　BIG　くじ指定試合</td>
# </tr>
# ----------------
# 1
# <tr>
# <th class="type4" width="128">販売開始日</th>
# <td class="type5">2019年03月02日（土）（ネット 12:50
#
#
#                                      ／toto取扱コンビニ 11:30
#
#
#
#
#                                      ／toto売り場 12:00）
#
#                                     </td>
# </tr>
# ----------------
# 2
# <tr>
# <th class="type4">販売終了日</th>
# <td class="type5">2019年03月09日（土）（ネット 13:50
#
#
#                                      ／toto取扱コンビニ 11:30
#
#
#
#                                      ／toto売り場 12:00）
#
#                                     </td>
# </tr>
# ----------------
# 3
# <tr>
# <th class="type4">結果発表日</th>
# <td class="type5">2019年03月10日（日）</td>
# </tr>
# ----------------
# 4
# <tr>
# <th width="50"> </th>
# <th width="78">開催日</th>
# <th width="90">試合開始<br/>
# ...

# %%
url = 'http://sport-kuji.toto-dream.com/dci/I/IPA/IPA02.do?op=dispBIGLotAssignGameDetail&popupDispDiv=0&holdCntId=1075&bigLotInfoCommodityId=&commodityId=13'
r = requests.get(url)
soup = BeautifulSoup(r.text, "html.parser")
rows = soup.find_all('tr')
for r in range(len(rows)):
    print(r)
    print(rows[r])
    print('----------------')
# Out:
# 0
# <tr>
# <th width="119">
# <img alt="100円BIG" height="39" src="http://sport-kuji.toto-dream.com/img_system/common/img_hyakuenBIG.gif" width="117"/>
# </th>
# <td>第1075回　100円BIG　くじ指定試合</td>
# </tr>
# ----------------
# 1
# <tr>
# <th class="type4" width="128">販売開始日</th>
# <td class="type5">2019年03月02日（土）（ネット 12:50
#
#
#                                      ／toto取扱コンビニ 11:30
#
#
#
#
#                                      ／toto売り場 12:00）
#
#                                     </td>
# </tr>
# ----------------
# 2
# <tr>
# <th class="type4">販売終了日</th>
# <td class="type5">2019年03月09日（土）（ネット 13:50
#
#
#                                      ／toto取扱コンビニ 11:30
#
#
#
#                                      ／toto売り場 12:00）
#
#                                     </td>
# </tr>
# ----------------
# 3
# <tr>
# <th class="type4">結果発表日</th>
# <td class="type5">2019年03月10日（日）</td>
# </tr>
# ----------------
# 4
# <tr>
# <th width="50"> </th>
# <th width="78">開催日</th>
# <th width="90">試合開始<br/>
# ...

# %%
url = 'http://sport-kuji.toto-dream.com/dci/I/IPA/IPA02.do?op=dispBIGLotAssignGameDetail&popupDispDiv=0&holdCntId=1075&bigLotInfoCommodityId=&commodityId=11'
r = requests.get(url)
soup = BeautifulSoup(r.text, "html.parser")
rows = soup.find_all('tr')
for r in range(len(rows)):
    print(r)
    print(rows[r])
    print('----------------')
# Out:
# 0
# <tr>
# <th width="119">
# <img alt="BIG1000" height="39" src="http://sport-kuji.toto-dream.com/img_system/common/img_big1000.gif" width="117"/>
# </th>
# <td>第1075回　BIG1000　くじ指定試合</td>
# </tr>
# ----------------
# 1
# <tr>
# <th class="type4" width="128">販売開始日</th>
# <td class="type5">2019年03月02日（土）（ネット 12:50
#
#
#                                      ／toto取扱コンビニ 11:30
#
#
#
#
#                                      ／toto売り場 12:00）
#
#                                     </td>
# </tr>
# ----------------
# 2
# <tr>
# <th class="type4">販売終了日</th>
# <td class="type5">2019年03月09日（土）（ネット 13:50
#
#
#                                      ／toto取扱コンビニ 11:30
#
#
#
#                                      ／toto売り場 12:00）
#
#                                     </td>
# </tr>
# ----------------
# 3
# <tr>
# <th class="type4">結果発表日</th>
# <td class="type5">2019年03月10日（日）</td>
# </tr>
# ----------------
# 4
# <tr>
# <th width="50"> </th>
# <th width="78">開催日</th>
# <th width="90">試合開始<br/>
# ...

# %%
url = 'http://sport-kuji.toto-dream.com/dci/I/IPA/IPA02.do?op=dispBIGLotAssignGameDetail&popupDispDiv=0&holdCntId=1075&bigLotInfoCommodityId=&commodityId=10'
r = requests.get(url)
soup = BeautifulSoup(r.text, "html.parser")
rows = soup.find_all('tr')
for r in range(len(rows)):
    print(r)
    print(rows[r])
    print('----------------')
# Out:
# 0
# <tr>
# <th width="119">
# <img alt="miniBIG" height="39" src="http://sport-kuji.toto-dream.com/img_system/common/img_minibig.gif" width="117"/>
# </th>
# <td>第1075回　mini BIG　くじ指定試合</td>
# </tr>
# ----------------
# 1
# <tr>
# <th class="type4" width="128">販売開始日</th>
# <td class="type5">2019年03月02日（土）（ネット 12:50
#
#
#                                      ／toto取扱コンビニ 11:30
#
#
#
#
#                                      ／toto売り場 12:00）
#
#                                     </td>
# </tr>
# ----------------
# 2
# <tr>
# <th class="type4">販売終了日</th>
# <td class="type5">2019年03月09日（土）（ネット 13:50
#
#
#                                      ／toto取扱コンビニ 11:30
#
#
#
#                                      ／toto売り場 12:00）
#
#                                     </td>
# </tr>
# ----------------
# 3
# <tr>
# <th class="type4">結果発表日</th>
# <td class="type5">2019年03月10日（日）</td>
# </tr>
# ----------------
# 4
# <tr>
# <th width="50"> </th>
# <th width="78">開催日</th>
# <th width="90">試合開始<br/>
# ...

# %%
rows[5]
# Out:
# <tr class="backgray">
# <td>1</td>
# <td>03/09</td>
# <td>14:00</td>
# <td>札幌ド</td>
# <td width="230">北海道コンサドーレ札幌</td>
# <td width="50">VS</td>
# <td>清水エスパルス</td>
# </tr>

# %%
tds = rows[5].find_all('td')
print(zenhan.z2h(tds[4].get_text()))
print(zenhan.z2h(tds[6].get_text()))
# Out:
# 北海道ｺﾝｻﾄﾞｰﾚ札幌
# 清水ｴｽﾊﾟﾙｽ

# %%
toto, n_match = get_all_data('miniBIG')
thtml = toto.to_html(classes='table', index=False)

# %%
from app.scripts.scraping import get_all_data

# %%
cd ..
# Out:
# /Users/jngt/Documents/toto

# %%
toto
# Out:
# '<table border="1" class="dataframe table">\n  <thead>\n    <tr style="text-align: right;">\n      <th>home</th>\n      <th>score</th>\n      <th>away</th>\n      <th>status</th>\n      <th>result</th>\n      <th>prediction</th>\n      <th>match</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <td>札幌</td>\n      <td>5\xa0-\xa02</td>\n      <td>清水</td>\n      <td>試合終了</td>\n      <td>1</td>\n      <td>0</td>\n      <td>X</td>\n    </tr>\n    <tr>\n      <td>磐田</td>\n      <td>1\xa0-\xa02</td>\n      <td>大分</td>\n      <td>試合終了</td>\n      <td>2</td>\n      <td>0</td>\n      <td>X</td>\n    </tr>\n    <tr>\n      <td>G大阪</td>\n      <td>2\xa0-\xa03</td>\n      <td>名古屋</td>\n      <td>試合終了</td>\n      <td>2</td>\n      <td>0</td>\n      <td>X</td>\n    </tr>\n    <tr>\n      <td>鹿島</td>\n      <td>1\xa0-\xa00</td>\n      <td>湘南</td>\n      <td>試合終了</td>\n      <td>1</td>\n      <td>0</td>\n      <td>X</td>\n    </tr>\n    <tr>\n      <td>C大阪</td>\n      <td>0\xa0-\xa01</td>\n    
# ...

# %%
soup = BeautifulSoup(thtml, "html.parser")

# %%
soup
# Out:
# <table border="1" class="dataframe table">
# <thead>
# <tr style="text-align: right;">
# <th>home</th>
# <th>score</th>
# <th>away</th>
# <th>status</th>
# <th>result</th>
# <th>prediction</th>
# <th>match</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>札幌</td>
# <td>5 - 2</td>
# <td>清水</td>
# <td>試合終了</td>
# <td>1</td>
# <td>0</td>
# <td>X</td>
# </tr>
# <tr>
# <td>磐田</td>
# <td>1 - 2</td>
# <td>大分</td>
# <td>試合終了</td>
# <td>2</td>
# <td>0</td>
# <td>X</td>
# </tr>
# <tr>
# <td>G大阪</td>
# <td>2 - 3</td>
# <td>名古屋</td>
# <td>試合終了</td>
# <td>2</td>
# <td>0</td>
# <td>X</td>
# </tr>
# <tr>
# <td>鹿島</td>
# <td>1 - 0</td>
# <td>湘南</td>
# <td>試合終了</td>
# <td>1</td>
# <td>0</td>
# <td>X</td>
# </tr>
# <tr>
# <td>C大阪</td>
# <td>0 - 1</td>
# <td>広島</td>
# <td>試合終了</td>
# <td>2</td>
# <td>0</td>
# <td>X</td>
# </tr>
# <tr>
# <td>松本</td>
# <td>0 - 1</td>
# <td>浦和</td>
# <td>試合終了</td>
# <td>2</td>
# <td>0</td>
# <td>X</td>
# </tr>
# <tr>
# <td>仙台</td>
# <td>1 - 3</td>
# <td>神戸</td>
# ...

# %%
rows = soup.find_all("tr")

# %%
len(rows)
# Out:
# 10

# %%
tds = rows[1].find_all("td")

# %%
tds
# Out:
# [<td>札幌</td>,
#  <td>5 - 2</td>,
#  <td>清水</td>,
#  <td>試合終了</td>,
#  <td>1</td>,
#  <td>0</td>,
#  <td>X</td>]

# %%
new_tag = soup.new_tag('td')
new_tag.string = '湘南'
tds[0].replace_with(new_tag)
# Out:
# <td>札幌</td>

# %%
new_tag
# Out:
# <td>湘南</td>

# %%
tds[0] = new_tag

# %%
tds
# Out:
# [<td>湘南</td>,
#  <td>5 - 2</td>,
#  <td>清水</td>,
#  <td>試合終了</td>,
#  <td>1</td>,
#  <td>0</td>,
#  <td>X</td>]

# %%
type(tds)
# Out:
# bs4.element.ResultSet

# %%
soup
# Out:
# <table border="1" class="dataframe table">
# <thead>
# <tr style="text-align: right;">
# <th>home</th>
# <th>score</th>
# <th>away</th>
# <th>status</th>
# <th>result</th>
# <th>prediction</th>
# <th>match</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>湘南</td>
# <td>5 - 2</td>
# <td>清水</td>
# <td>試合終了</td>
# <td>1</td>
# <td>0</td>
# <td>X</td>
# </tr>
# <tr>
# <td>磐田</td>
# <td>1 - 2</td>
# <td>大分</td>
# <td>試合終了</td>
# <td>2</td>
# <td>0</td>
# <td>X</td>
# </tr>
# <tr>
# <td>G大阪</td>
# <td>2 - 3</td>
# <td>名古屋</td>
# <td>試合終了</td>
# <td>2</td>
# <td>0</td>
# <td>X</td>
# </tr>
# <tr>
# <td>鹿島</td>
# <td>1 - 0</td>
# <td>湘南</td>
# <td>試合終了</td>
# <td>1</td>
# <td>0</td>
# <td>X</td>
# </tr>
# <tr>
# <td>C大阪</td>
# <td>0 - 1</td>
# <td>広島</td>
# <td>試合終了</td>
# <td>2</td>
# <td>0</td>
# <td>X</td>
# </tr>
# <tr>
# <td>松本</td>
# <td>0 - 1</td>
# <td>浦和</td>
# <td>試合終了</td>
# <td>2</td>
# <td>0</td>
# <td>X</td>
# </tr>
# <tr>
# <td>仙台</td>
# <td>1 - 3</td>
# <td>神戸</td>
# ...

# %%
for i in range(len(rows)):
    print(i)
    print(rows[i])
    print('-------------------------------')
# Out:
# 0
# <tr style="text-align: right;">
# <th>home</th>
# <th>score</th>
# <th>away</th>
# <th>status</th>
# <th>result</th>
# <th>prediction</th>
# <th>match</th>
# </tr>
# -------------------------------
# 1
# <tr>
# <td>湘南</td>
# <td>5 - 2</td>
# <td>清水</td>
# <td>試合終了</td>
# <td>1</td>
# <td>0</td>
# <td>X</td>
# </tr>
# -------------------------------
# 2
# <tr>
# <td>磐田</td>
# <td>1 - 2</td>
# <td>大分</td>
# <td>試合終了</td>
# <td>2</td>
# <td>0</td>
# <td>X</td>
# </tr>
# -------------------------------
# 3
# <tr>
# <td>G大阪</td>
# <td>2 - 3</td>
# <td>名古屋</td>
# <td>試合終了</td>
# <td>2</td>
# <td>0</td>
# <td>X</td>
# </tr>
# -------------------------------
# 4
# <tr>
# <td>鹿島</td>
# <td>1 - 0</td>
# <td>湘南</td>
# <td>試合終了</td>
# <td>1</td>
# <td>0</td>
# <td>X</td>
# </tr>
# -------------------------------
# 5
# <tr>
# <td>C大阪</td>
# <td>0 - 1</td>
# <td>広島</td>
# <td>試合終了</td>
# <td>2</td>
# <td>0</td>
# <td>X</td>
# </tr>
# -------------------------------
# 6
# <tr>
# <td>松本</td>
# ...

# %%
tds[0]
# Out:
# <td>湘南</td>

# %%
new_tag = soup.new_tag('td')
new_tag.string = 'レアル'

# %%
tds[0] = tds[0].replace_with(new_tag)

# %%
tds
# Out:
# [<td>湘南</td>,
#  <td>5 - 2</td>,
#  <td>清水</td>,
#  <td>試合終了</td>,
#  <td>1</td>,
#  <td>0</td>,
#  <td>X</td>]

# %%
tds
# Out:
# [<td>湘南</td>,
#  <td>5 - 2</td>,
#  <td>清水</td>,
#  <td>試合終了</td>,
#  <td>1</td>,
#  <td>0</td>,
#  <td>X</td>]

# %%
new_tag = soup.new_tag('input', type='text')

# %%
new_tag
# Out:
# <input type="text"/>

# %%
tds
# Out:
# [<td>湘南</td>,
#  <td>5 - 2</td>,
#  <td>清水</td>,
#  <td>試合終了</td>,
#  <td>1</td>,
#  <td>0</td>,
#  <td>X</td>]

# %%
input_tag = soup.new_tag('input', type='text', value=tds[5].text)

# %%
input_tag
# Out:
# <input type="text" value="0"/>

# %%
tds[5]
# Out:
# <td>0</td>

# %%
tds[5].string
# Out:
# '0'

# %%
tds[5].get_text()
# Out:
# '0'

# %%
tds[5].text
# Out:
# '0'

# %%
tds[5].append(input_tag)

# %%
tds
# Out:
# [<td>湘南</td>,
#  <td>5 - 2</td>,
#  <td>清水</td>,
#  <td>試合終了</td>,
#  <td>1</td>,
#  <td>0<input type="text" value="0"/></td>,
#  <td>X</td>]

# %%
tds[5] = input_tag.wrap(soup.new_tag('td'))

# %%
tds
# Out:
# [<td>湘南</td>,
#  <td>5 - 2</td>,
#  <td>清水</td>,
#  <td>試合終了</td>,
#  <td>1</td>,
#  <td><input type="text" value="0"/></td>,
#  <td>X</td>]

# %%
html_content = soup.prettify()

# %%
html_content
# Out:
# '<table border="1" class="dataframe table">\n <thead>\n  <tr style="text-align: right;">\n   <th>\n    home\n   </th>\n   <th>\n    score\n   </th>\n   <th>\n    away\n   </th>\n   <th>\n    status\n   </th>\n   <th>\n    result\n   </th>\n   <th>\n    prediction\n   </th>\n   <th>\n    match\n   </th>\n  </tr>\n </thead>\n <tbody>\n  <tr>\n   <td>\n    レアル\n   </td>\n   <td>\n    5\xa0-\xa02\n   </td>\n   <td>\n    清水\n   </td>\n   <td>\n    試合終了\n   </td>\n   <td>\n    1\n   </td>\n   <td>\n    0\n    <td>\n     <input type="text" value="0"/>\n    </td>\n   </td>\n   <td>\n    X\n   </td>\n  </tr>\n  <tr>\n   <td>\n    磐田\n   </td>\n   <td>\n    1\xa0-\xa02\n   </td>\n   <td>\n    大分\n   </td>\n   <td>\n    試合終了\n   </td>\n   <td>\n    2\n   </td>\n   <td>\n    0\n   </td>\n   <td>\n    X\n   </td>\n  </tr>\n  <tr>\n   <td>\n    G大阪\n   </td>\n   <td>\n    2\xa0-\xa03\n   </td>\n   <td>\n    名古屋\n   </td>\n   <td>\n    試合終了\n   </td>\n   <td>\n    2\n   </td>\n   <td>\n    0\n   </
# ...

# %%
soup
# Out:
# <table border="1" class="dataframe table">
# <thead>
# <tr style="text-align: right;">
# <th>home</th>
# <th>score</th>
# <th>away</th>
# <th>status</th>
# <th>result</th>
# <th>prediction</th>
# <th>match</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>レアル</td>
# <td>5 - 2</td>
# <td>清水</td>
# <td>試合終了</td>
# <td>1</td>
# <td>0<td><input type="text" value="0"/></td></td>
# <td>X</td>
# </tr>
# <tr>
# <td>磐田</td>
# <td>1 - 2</td>
# <td>大分</td>
# <td>試合終了</td>
# <td>2</td>
# <td>0</td>
# <td>X</td>
# </tr>
# <tr>
# <td>G大阪</td>
# <td>2 - 3</td>
# <td>名古屋</td>
# <td>試合終了</td>
# <td>2</td>
# <td>0</td>
# <td>X</td>
# </tr>
# <tr>
# <td>鹿島</td>
# <td>1 - 0</td>
# <td>湘南</td>
# <td>試合終了</td>
# <td>1</td>
# <td>0</td>
# <td>X</td>
# </tr>
# <tr>
# <td>C大阪</td>
# <td>0 - 1</td>
# <td>広島</td>
# <td>試合終了</td>
# <td>2</td>
# <td>0</td>
# <td>X</td>
# </tr>
# <tr>
# <td>松本</td>
# <td>0 - 1</td>
# <td>浦和</td>
# <td>試合終了</td>
# <td>2</td>
# <td>0</td>
# <td>X</td>
# </tr>
# <tr>
# <td>仙台</td>
# ...

# %%
thtml
# Out:
# '<table border="1" class="dataframe table">\n  <thead>\n    <tr style="text-align: right;">\n      <th>home</th>\n      <th>score</th>\n      <th>away</th>\n      <th>status</th>\n      <th>result</th>\n      <th>prediction</th>\n      <th>match</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <td>札幌</td>\n      <td>5\xa0-\xa02</td>\n      <td>清水</td>\n      <td>試合終了</td>\n      <td>1</td>\n      <td>0</td>\n      <td>X</td>\n    </tr>\n    <tr>\n      <td>磐田</td>\n      <td>1\xa0-\xa02</td>\n      <td>大分</td>\n      <td>試合終了</td>\n      <td>2</td>\n      <td>0</td>\n      <td>X</td>\n    </tr>\n    <tr>\n      <td>G大阪</td>\n      <td>2\xa0-\xa03</td>\n      <td>名古屋</td>\n      <td>試合終了</td>\n      <td>2</td>\n      <td>0</td>\n      <td>X</td>\n    </tr>\n    <tr>\n      <td>鹿島</td>\n      <td>1\xa0-\xa00</td>\n      <td>湘南</td>\n      <td>試合終了</td>\n      <td>1</td>\n      <td>0</td>\n      <td>X</td>\n    </tr>\n    <tr>\n      <td>C大阪</td>\n      <td>0\xa0-\xa01</td>\n    
# ...

# %%
soup = BeautifulSoup(thtml, "html.parser")
rows = soup.find_all("tr")
for i in range(1, len(rows)):
    tds = rows[i].find_all("td")
    input_tag = soup.new_tag('input', type='text', value=tds[5].text)
    tds[5] = input_tag.wrap(soup.new_tag('td'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-67-54e31f1e03ed> in <module>()
#       4     tds = rows[i].find_all("td")
#       5     input_tag = soup.new_tag('input', type='text', value=tds[5].text)
# ----> 6     tds[5] = input_tag.wrap(soup.new_tag('td'))
#
# /Users/jngt/anaconda/lib/python3.6/site-packages/bs4/element.py in wrap(self, wrap_inside)
#     261
#     262     def wrap(self, wrap_inside):
# --> 263         me = self.replace_with(wrap_inside)
#     264         wrap_inside.append(me)
#     265         return wrap_inside
#
# /Users/jngt/anaconda/lib/python3.6/site-packages/bs4/element.py in replace_with(self, replace_with)
#     233         if not self.parent:
#     234             raise ValueError(
# --> 235                 "Cannot replace one element with another when the"
#     236                 "element to be replaced is not part of a tree.")
# ...

# %%
input_tag = soup.new_tag('input', type='text', value=tds[5].text)

# %%
tds
# Out:
# [<td>札幌</td>,
#  <td>5 - 2</td>,
#  <td>清水</td>,
#  <td>試合終了</td>,
#  <td>1</td>,
#  <td>0</td>,
#  <td>X</td>]

# %%
tds[5] = input_tag.wrap(soup.new_tag('td'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-70-4aed0d78df46> in <module>()
# ----> 1 tds[5] = input_tag.wrap(soup.new_tag('td'))
#
# /Users/jngt/anaconda/lib/python3.6/site-packages/bs4/element.py in wrap(self, wrap_inside)
#     261
#     262     def wrap(self, wrap_inside):
# --> 263         me = self.replace_with(wrap_inside)
#     264         wrap_inside.append(me)
#     265         return wrap_inside
#
# /Users/jngt/anaconda/lib/python3.6/site-packages/bs4/element.py in replace_with(self, replace_with)
#     233         if not self.parent:
#     234             raise ValueError(
# --> 235                 "Cannot replace one element with another when the"
#     236                 "element to be replaced is not part of a tree.")
#     237         if replace_with is self:
#
# ...

# %%
type(tds)
# Out:
# bs4.element.ResultSet

# %%
tds[5]
# Out:
# <td>0</td>

# %%
type(input_tag)
# Out:
# bs4.element.Tag

# %%
input_tag = .new_tag('input', type='text', value=tds[5].text)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-75-5a16f3be799e> in <module>()
# ----> 1 input_tag = tds[0].new_tag('input', type='text', value=tds[5].text)
#
# TypeError: 'NoneType' object is not callable

# %%
type(soup.new_tag('td'))
# Out:
# bs4.element.Tag

# %%
type(input_tag)
# Out:
# bs4.element.Tag

# %%
input_tag.wrap(soup.new_tag('td'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-81-e49c7ade0951> in <module>()
# ----> 1 input_tag.wrap(soup.new_tag('td'))
#
# /Users/jngt/anaconda/lib/python3.6/site-packages/bs4/element.py in wrap(self, wrap_inside)
#     261
#     262     def wrap(self, wrap_inside):
# --> 263         me = self.replace_with(wrap_inside)
#     264         wrap_inside.append(me)
#     265         return wrap_inside
#
# /Users/jngt/anaconda/lib/python3.6/site-packages/bs4/element.py in replace_with(self, replace_with)
#     233         if not self.parent:
#     234             raise ValueError(
# --> 235                 "Cannot replace one element with another when the"
#     236                 "element to be replaced is not part of a tree.")
#     237         if replace_with is self:
#
# ...

# %%
tds[5] = input_tag

# %%
tds
# Out:
# [<td>札幌</td>,
#  <td>5 - 2</td>,
#  <td>清水</td>,
#  <td>試合終了</td>,
#  <td>1</td>,
#  <input type="text" value="0"/>,
#  <td>X</td>]

# %%
tds[5].string

# %%
tds[4].string.replace_with(input_tag)
# Out:
# '1'

# %%
tds
# Out:
# [<td>札幌</td>,
#  <td>5 - 2</td>,
#  <td>清水</td>,
#  <td>試合終了</td>,
#  <td><input type="text" value="0"/></td>,
#  <input type="text" value="0"/>,
#  <td>X</td>]

# %%
soup = BeautifulSoup('<form></form>', "html.parser")

# %%
flag = 'minitotoA'

# %%
soup.form["action"] = '/' + flag
soup.form["method"] = 'post'

# %%
soup.form
# Out:
# <form action="/minitotoA" method="post"></form>

# %%
soup.new_tag('button', value = True).wrap(soup.form)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-111-d3aa6eeb2657> in <module>()
# ----> 1 soup.new_tag('button', value = True).wrap(soup.form)
#
# /Users/jngt/anaconda/lib/python3.6/site-packages/bs4/element.py in wrap(self, wrap_inside)
#     261
#     262     def wrap(self, wrap_inside):
# --> 263         me = self.replace_with(wrap_inside)
#     264         wrap_inside.append(me)
#     265         return wrap_inside
#
# /Users/jngt/anaconda/lib/python3.6/site-packages/bs4/element.py in replace_with(self, replace_with)
#     233         if not self.parent:
#     234             raise ValueError(
# --> 235                 "Cannot replace one element with another when the"
#     236                 "element to be replaced is not part of a tree.")
#     237         if replace_with is self:
#
# ...

# %%
soup.form.wrap(soup.new_tag('button', value = True))
# Out:
# <button value="True"><form action="/minitotoA" method="post"></form></button>

# %%
    <form action="/{{ flag }}" method="post">
        <button name="post_value" value="from post">post submit</button>
    </form>

# %%
soup = BeautifulSoup('<button></button>', "html.parser")

# %%
soup.button['value'] = True

# %%
soup.button.string = 'Input'

# %%
soup
# Out:
# <button>Input</button>

# %%
soup.button.wrap(soup.new_tag('form', action= '/' + flag, method='post'))
# Out:
# <form action="/minitotoA" method="post"><button value="True">Input</button></form>

# %%
"location.href='/{}'".format(flag)
# Out:
# "location.href='/minitotoA'"

# %%
soup.button['name'] = 'post_value'

# %%
soup
# Out:
# <button name="post_value" onclick="location.href='/minitotoA'">Input</button>

# %%
soup.button['onclick'] = "location.href='/{}'".format(flag)

# %%
soup
# Out:
# <button onclick="location.href='/minitotoA'">Input</button>

# %%
soup.append(soup.new_tag('a'))

# %%
soup
# Out:
# <button name="post_value" onclick="location.href='/minitotoA'">Input</button><a></a>

# %%
    <label><input type="checkbox" name="fav" value="1">ラーメン</label>
    <label><input type="checkbox" name="fav" value="2">うな丼</label>
    <label><input type="checkbox" name="fav" value="3">メロン</label>

# %%
cb_tag1 = soup.new_tag('input', type='checkbox', value='1', checked=True)
cb_tag1['name'] = 'in' + str(i)
cb_tag1.string = '1'

# %%
cb_tag1
# Out:
# <input checked="True" name="in1" type="checkbox" value="1">1</input>

# %%
tds[4]
# Out:
# <td><input type="text" value="0"/></td>

# %%
tds[4].unwrap()
# Out:
# <td></td>

# %%
tds[4].string='0'

# %%
tds[4]
# Out:
# <td>0</td>

# %%
tds[4].string=''

# %%
tds[4]
# Out:
# <td></td>

# %%
tds[4].append(input_tag)

# %%
tds[4]
# Out:
# <td><input type="text" value="0"/></td>

# %%
tds[4].append(cb_tag1)

# %%
tds
# Out:
# [<td>札幌</td>,
#  <td>5 - 2</td>,
#  <td>清水</td>,
#  <td>試合終了</td>,
#  <td><input type="text" value="0"/><input checked="True" name="in1" type="checkbox" value="1">1</input></td>,
#  <input type="text" value="0"/>,
#  <td>X</td>]

# %%
a = ['0','1']

# %%
'2' in a
# Out:
# False

# %%
'0' in a
# Out:
# True

# %%
now = '1075'

# %%
url = 'http://sport-kuji.toto-dream.com/dci/I/IPA/IPA02.do?op=dispBIGLotInfo&holdCntId=' + now

# %%
r = requests.get(url )
soup = BeautifulSoup(r.text, "html.parser")

# %%
soup
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
#
# <html>
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="text/javascript" http-equiv="Content-Script-Type"/>
# <meta content="text/css" http-equiv="Content-Style-Type"/>
# <link href="/dci/css/P/PZZ/PZZ07/main.css" rel="stylesheet" type="text/css"/>
# <title>toto公式サイト-ロト６、宝くじと並ぶ高額当せんくじＢＩＧ。目指せ最高6億円！</title>
# <script src="//assets.adobedtm.com/3fb4a95d593e4b420e11f482b00de674bf8ed253/satelliteLib-fd2c7fee3ce1783ec86f3eca0f012a26a4f8db32.js"></script>
# <script src="/dci/js/P/PZZ/PZZOL/common.js" type="text/javascript"></script>
# <script src="/dci/js/P/PZZ/PZZOL/common_check.js" type="text/javascript"></script>
# <script src="/dci/js/P/PZZ/PZZOL/common_message.js" type="text/javascript"></script>
# <script type="text/javascript">
# <!--
# //BIG試合詳細へ
# //引継情報　商品ID、開催回ID、ポップアップ表示区分
# function doSubmitGamesInfoBIG(form, op, action) {
# ...

# %%
r = requests.get('http://sport-kuji.toto-dream.com/dci/I/IPA/IPA02.do?op=dispBIGLotInfo&holdCntId=1077')
soup = BeautifulSoup(r.text, "html.parser")

# %%
soup
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
#
# <html>
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="text/javascript" http-equiv="Content-Script-Type"/>
# <meta content="text/css" http-equiv="Content-Style-Type"/>
# <link href="/dci/css/P/PZZ/PZZ07/main.css" rel="stylesheet" type="text/css"/>
# <title>toto公式サイト-ロト６、宝くじと並ぶ高額当せんくじＢＩＧ。目指せ最高6億円！</title>
# <script src="//assets.adobedtm.com/3fb4a95d593e4b420e11f482b00de674bf8ed253/satelliteLib-fd2c7fee3ce1783ec86f3eca0f012a26a4f8db32.js"></script>
# <script src="/dci/js/P/PZZ/PZZOL/common.js" type="text/javascript"></script>
# <script src="/dci/js/P/PZZ/PZZOL/common_check.js" type="text/javascript"></script>
# <script src="/dci/js/P/PZZ/PZZOL/common_message.js" type="text/javascript"></script>
# <script type="text/javascript">
# <!--
# //BIG試合詳細へ
# //引継情報　商品ID、開催回ID、ポップアップ表示区分
# function doSubmitGamesInfoBIG(form, op, action) {
# ...

# %%
soup.find('a', href="#HyakuenBig")
# Out:
# <a href="#HyakuenBig">100円BIG</a>

# %%
a

# %%
r = requests.get('http://sport-kuji.toto-dream.com/dci/I/IPA/IPA02.do?op=dispBIGLotInfo&holdCntId=1076')
soup = BeautifulSoup(r.text, "html.parser")

# %%
soup
# Out:
# <html>
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <title>toto公式サイト-ロト６、宝くじと並ぶ高額当せんくじＢＩＧ。目指せ最高6億円！</title>
# <link href="/dci/css/P/PZZ/PZZ04/toweb2.css" rel="stylesheet" type="text/css"/>
# <link href="/dci/css/P/PZZ/PZZ04/main.css" rel="stylesheet" type="text/css"/>
# <link href="http://sport-kuji.toto-dream.com/static_common_system/css/headerfooter.css" rel="stylesheet" type="text/css"/>
# <script src="http://sport-kuji.toto-dream.com/static_common_system/js/swpimg.js" type="text/javascript"></script>
# </head>
# <body>
# <link href="http://sport-kuji.toto-dream.com/static_common_system/css/headerlogo.css" rel="stylesheet" type="text/css"/>
# <div class="clearfix" id="dynmember-header-wrapper">
# <div id="header-base">
# <div id="header-contents">
# <div class="headerTopLeft">
# ...

# %%
soup.find_all('a', href="#HyakuenBig")
# Out:
# []

# %%
r = requests.get('http://sport-kuji.toto-dream.com/dci/I/IPA/IPA01.do?op=disptotoLotInfo&holdCntId=1076')
soup = BeautifulSoup(r.text, "html.parser")

# %%
soup.find_all('a', href="#toto")
# Out:
# [<a href="#toto">toto</a>,
#  <a href="#toto">toto</a>,
#  <a href="#toto">toto</a>,
#  <a href="#toto">toto</a>]

# %%
soup
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
#
# <html>
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="text/javascript" http-equiv="Content-Script-Type"/>
# <meta content="text/css" http-equiv="Content-Style-Type"/>
# <link href="/dci/css/P/PZZ/PZZ07/main.css" rel="stylesheet" type="text/css"/>
# <title>toto公式サイト-ロト６、宝くじと並ぶ高額当せんくじＢＩＧ。目指せ最高6億円！</title>
# <script src="//assets.adobedtm.com/3fb4a95d593e4b420e11f482b00de674bf8ed253/satelliteLib-fd2c7fee3ce1783ec86f3eca0f012a26a4f8db32.js"></script>
# <script src="/dci/js/P/PZZ/PZZOL/common.js" type="text/javascript"></script>
# <script src="/dci/js/P/PZZ/PZZOL/common_check.js" type="text/javascript"></script>
# <script src="/dci/js/P/PZZ/PZZOL/common_message.js" type="text/javascript"></script>
# <script type="text/javascript">
#         <!--
#         function doSubmitOnce(form, op, action) {
#             if (submitOnce()) {
# ...

# %%
soup.find_all('a', href="#toto")
# Out:
# []

# %%
a = 'HyakuenBig'

# %%
'BIG' in a
# Out:
# False

# %%
rows = {}
url = 'https://soccer.yahoo.co.jp/jleague/league/'
r = requests.get(url + 'yn')
soup = BeautifulSoup(r.text, "html.parser")

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ja">
# <head>
# <title>Jリーグ - Jリーグ杯 - スポーツナビ</title>
# <meta charset="utf-8"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="Jリーグ杯（ルヴァンカップ） トップページ。スポーツ総合サイト、スポーツナビ(スポナビ)のJリーグページです。最新のニュース､速報、日程、見所、結果、順位、ゴールランキング、選手名鑑情報、プレーオフなどを素早くお届けします。" name="description"/>
# <meta content="Jリーグ,Jリーグ杯,ルヴァンカップ,2019,日程結果,試合速報,順位表" name="keywords"/>
# <meta content="Jリーグ - Jリーグ杯 - スポーツナビ" property="og:title">
# <meta content="website" property="og:type">
# <meta content="https://soccer.yahoo.co.jp/jleague/league/yn" property="og:url">
# <meta content="https://s.yimg.jp/images/sports/all_device/common/ogp/soccer.png" property="og:image">
# <meta content="スポーツナビ" property="og:site_name"/>
# <meta content="Jリーグ杯（ルヴァンカップ） トップページ。スポーツ総合サイト、スポーツナビ(スポナビ)のJリーグページです。最新のニュース､速報、日程、見所、結果、順位、ゴールランキング、選手名鑑情報、プレーオフなどを素早くお届けします。" property="og:description"/>
# <meta content="ja_JP" property="og:locale"/>
# ...

# %%
soup.tbody.find_all('tr')
# Out:
# [<tr>
#  <td class="textC">3/13（水）<br/>19:00</td><td class="team">
#  <a class="logo" data-ylk="slk:logo_con;pos:0" href="https://soccer.yahoo.co.jp/jleague/teams/detail/276"><span aria-hidden="true" class="sn-icon sn-icon--jleagueTeam276"><img alt="" height="30" oncontextmenu="javascript:return false;" src="https://s.yimg.jp/images/sports/all_device/pc/img/clear.gif" width="30"/></span></a><a data-ylk="slk:text_con;pos:0" href="https://soccer.yahoo.co.jp/jleague/teams/detail/276">札幌</a>
#  </td>
#  <td class="score">
#  <a data-ylk="slk:score_p;pos:1" href="/jleague/game/score/2019031305">スタメン</a>
#  <small class="status"></small>
#  </td>
#  <td class="team">
# ...

# %%
soup.find_all('tbody')
# Out:
# [<tbody>
#  <tr>
#  <td class="textC">3/13（水）<br/>19:00</td><td class="team">
#  <a class="logo" data-ylk="slk:logo_con;pos:0" href="https://soccer.yahoo.co.jp/jleague/teams/detail/276"><span aria-hidden="true" class="sn-icon sn-icon--jleagueTeam276"><img alt="" height="30" oncontextmenu="javascript:return false;" src="https://s.yimg.jp/images/sports/all_device/pc/img/clear.gif" width="30"/></span></a><a data-ylk="slk:text_con;pos:0" href="https://soccer.yahoo.co.jp/jleague/teams/detail/276">札幌</a>
#  </td>
#  <td class="score">
#  <a data-ylk="slk:score_p;pos:1" href="/jleague/game/score/2019031305">スタメン</a>
#  <small class="status"></small>
#  </td>
#  <td class="team">
# ...
